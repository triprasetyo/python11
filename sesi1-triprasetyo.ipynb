# %% [markdown]
# # Integer = Bilangan Bulat

# %%
print(1000000000)
# Out:
# 1000000000

# %%
print(type(3))
# Out:
# <class 'int'>

# %% [markdown]
# # Float

# %%
print(3.5)
print(2.3)
# Out:
# 3.5
# 2.3

# %%
print(type(2.3))
# Out:
# <class 'float'>

# %%
print(4.2e-4)
# Out:
# 0.00042

# %%
print(type(4.2e7))
# Out:
# <class 'float'>

# %% [markdown]
# # String

# %%
print("Nama saya prasetyo")
# Out:
# Nama saya prasetyo

# %%
print("Pras bermain playstation")
# Out:
# Pras bermain playstation

# %%
print(type('Pras bermain playstation'))
# Out:
# <class 'str'>

# %% [markdown]
# # Boolean

# %%
True
False
# Out:
# False

# %%
print(True)
# Out:
# True

# %%
print(False)
# Out:
# False

# %%
print(type(True))
# Out:
# <class 'bool'>

# %% [markdown]
# Ada 4 data types yang paling sering digunakan
#
#
# *   Integer
# *   Float
# *   String
# *   Boolean

# %% [markdown]
# # Variabel Assignment

# %%
angka = 300
print(angka)
print(type(angka))
print(type(300))
# Out:
# 300
# <class 'int'>
# <class 'int'>

# %%
teks = 'haha'
print(teks)
print(type(teks))
# Out:
# haha
# <class 'str'>

# %%
a = b = c = 300
print(a,b,c)
# Out:
# 300 300 300

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
rumah = 'Bekasi'
Rumah = 'Jakarta'

# %%
print(rumah,rumah)
# Out:
# Bekasi Bekasi

# %% [markdown]
# ## Nama variabel tidak diperbolehkan dimulai dengan angka
# ## 0_Rumah='a'

# %%
# Nama variabel tidak diperbolehkan dimulai dengan angka
# 0_Rumah = 'a'

# %%
# rumah = 'budi'

# %%
print(rumah)
# Out:
# Bekasi

# %% [markdown]
# # Arithmetic Opeators

# %%
a = 10
b = 20
print(a + b)
# Out:
# 30

# %%
#pengurangan
print(a-b)
# Out:
# -10

# %%
#perkalian
print(a*b)
# Out:
# 200

# %%
#pembagian
print(a/b)
print(a//b)
print(3/2)
print(3//2)
print(type(3/2))
print(type(3//2))
# Out:
# 0.5
# 0
# 1.5
# 1
# <class 'float'>
# <class 'int'>

# %%
# modulo(%)
print(7/2)
print(7%2)
print(11%2)
print(10%2)
# Out:
# 3.5
# 1
# 1
# 0

# %%
# pangkat
print(7**2)
print(2**2)
# Out:
# 49
# 4

# %% [markdown]
# # Quiz 1 30 derajat celsius ke fahrenheit

# %%
c = 
f = 
print(f)
# Out:
#   File "<ipython-input-28-ed738a3ed76b>", line 1
#     c =
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Comparison Operators

# %%
c = 10
d = 30
e = 10
f = 20

# %%
rumah1 = 'bekasi'
rumah2 = 'jakarta'
rumah3 = 'jakarta'

# %%
# persamaan
print(c==d)
print(c==e)
print(rumah2==rumah3)
# Out:
# False
# True
# True

# %%
# lebih dari atau kurang dari
print(c>d)
print(c<d)
print(c>=d)
print(c<=d)
print(c<=e)
print(c>=e)
# Out:
# False
# True
# False
# True
# True
# True

# %%
# tidak sama dengan / not equal (!=)
print(c!=d)
print(c!=e)
print(rumah1!=rumah2)
# Out:
# True
# False
# True

# %% [markdown]
# # String Manipulation

# %%
#operator +
s = 'foo'
t = 'bar'
u = 'baz'

print(t+s)

print(s+t+u)
# Out:
# barfoo
# foobarbaz

# %%
#operator *
print(s*10)
# Out:
# foofoofoofoofoofoofoofoofoofoo

# %%
#operator in
a = 'buah'
print(a in 'saya mau beli buah')
print(a in 'saya mau beli singkong')
# Out:
# True
# False

# %%
#upper
a = 'buah'
print(a.upper())
# Out:
# BUAH

# %%
b = 'BUAH'
print(a.lower())
# Out:
# buah

# %%
c = 'sAyAc'
print(c.capitalize())
# Out:
# Sayac

# %%
d = 'SAya mAu Makan'
print(d.capitalize())
print(d.title())
print(d.swapcase())
# Out:
# Saya mau makan
# Saya Mau Makan
# saYA MaU mAKAN

# %% [markdown]
# # Python List

# %%
a = ['saya','mau','makan']
c = ['makan','mau','saya']

# %%
print(a)
# Out:
# ['saya', 'mau', 'makan']

# %%
b = ['saya',1,True,3.7]
print(b)
# Out:
# ['saya', 1, True, 3.7]

# %%
print(a==c)
# Out:
# False

# %% [markdown]
# # Indexing dan Slicing

# %%
# list can be accessed by Index
a = ['foo','bar','baz','qux','quux','corge']
print(a)
# Out:
# ['foo', 'bar', 'baz', 'qux', 'quux', 'corge']

# %%
# indexing
print(a[0])
print(a[3])
# Out:
# foo
# qux

# %%
print(a[-6])
# Out:
# foo

# %%
print(a[-6]==a[0])
# Out:
# True

# %%
x = 'budi'
print(x[-1])
# Out:
# i

# %% [markdown]
# # Prinsip Slicing = [start:stop:step]

# %%
# slicing
a = ['foo','baz','qux','quux','corge']
print(a[0:6])
print(a[1:])
# Out:
# ['foo', 'baz', 'qux', 'quux', 'corge']
# ['baz', 'qux', 'quux', 'corge']

# %%
x = 'budi'
print(x[1:3])
print(x[1:])
# Out:
# ud
# udi

# %%
y = 'Jaka tingkir suryanegara'
print(y[::-1])
# Out:
# aragenayrus rikgnit akaJ

# %%
a = 'komitmen'

# %% [markdown]
# > Exercise C
#
# Use indexing or slicing to get
#
# 1. i
# 2. omi
# 3. tmen
# 4. kmte
# 5. kmtn

# %%
print(a[0:5:2]+a[a.index('n')])
# Out:
# kmtn

# %% [markdown]
# # Modify List values based on its index

# %%
a = ['foo','bar','baz','qux','quux','corge','quux']
a[a.index('qux')] = 20

# %%
# del command
del a[a.index('quux')]
print(a)
# Out:
# ['foo', 'bar', 'baz', 20, 'corge', 'quux']

# %%
a = ['foo','bar','baz','qux','quux','corge','quux']
a[0:3] = [1,2,3]
print(a)
# Out:
# [1, 2, 3, 'qux', 'quux', 'corge', 'quux']

# %% [markdown]
# # Tuple

# %%
t = ('foo','bar','baz','qux','quux','corge','quux')
print(type(t))
# Out:
# <class 'tuple'>

# %%
t[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-c8aeb8cd20ae> in <module>
# ----> 1 t[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Dictionary

# %%
MLB_team = {
    'Colorado':'Rockies',
    'Boston':'Red Sox',
    'Minnesota':'Twins',
    'Milwaukee':'Brewers',
    'Seattle':'Mariners'
}

# %%
print(MLB_team['Colorado'])
print(MLB_team['Boston'])
# Out:
# Rockies
# Red Sox

# %%
# assign kota baru
MLB_team['Kansas City'] = 'Royals'
print(MLB_team)
# Out:
# {'Colorado': 'Rockies', 'Boston': 'Red Sox', 'Minnesota': 'Twins', 'Milwaukee': 'Brewers', 'Seattle': 'Mariners', 'Kansas City': 'Royals'}

# %%
# update tim kota
MLB_team['Seattle'] = 'Seahawks'
print(MLB_team)
# Out:
# {'Colorado': 'Rockies', 'Boston': 'Red Sox', 'Minnesota': 'Twins', 'Milwaukee': 'Brewers', 'Seattle': 'Seahawks', 'Kansas City': 'Royals'}

# %%
orang = {}
print(type(orang))
# Out:
# <class 'dict'>

# %%
orang['Nama'] = 'Pras'
orang['Kota'] = 'Depok'
orang['Umur'] = 32
orang['Anak'] = ['Vanya','Fabricia','Prasetyo']
orang['Kendaraan'] = {'mobil':'Avanza','motor':'beat'}
orang
# Out:
# {'Nama': 'Pras',
#  'Kota': 'Depok',
#  'Umur': 32,
#  'Anak': ['Vanya', 'Fabricia', 'Prasetyo'],
#  'Kendaraan': {'mobil': 'Avanza', 'motor': 'beat'}}

# %%
print(type(orang))
# Out:
# <class 'dict'>

# %%
print(orang['Kendaraan']['motor'])
# Out:
# beat

# %%
print(orang['Anak'][0:2])
# Out:
# ['Vanya', 'Fabricia']

# %% [markdown]
# # Line Continuation

# %%
print(True and True)
print(True and False)
print(True or True)
print(True or False)
print(False and False)
print(False or False)
# Out:
# True
# False
# True
# True
# False
# False

# %%
umur1 = 42
umur2 = 16
umur3 = 71
print(umur1>=18 and umur1<=65)
print(umur2>=18 and umur2<=65)
print(umur3>=18 and umur3<=65)
# Out:
# True
# False
# False

# %%
print((umur1>=18 and umur1<=65) or (umur2>=18 and umur2<=65) or (umur3>=18 and umur3<=65))
# Out:
# True

# %% [markdown]
# # Materi tambahan

# %%
mobil = ['Toyota','Kijang']
mobil = mobil + ['Isuzu']
print(mobil)
# Out:
# ['Toyota', 'Kijang', 'Isuzu']

# %%
mobil = ['Toyota','Kijang']
mobil.append('Isuzu')
print(mobil)
# Out:
# ['Toyota', 'Kijang', 'Isuzu']

# %%
kendaraan = mobil.copy()
print(kendaraan)
# Out:
# ['Toyota', 'Kijang', 'Isuzu']

# %%
kendaraan.append('Innova')
kendaraan.append('Innova')

print(kendaraan)
print(mobil)
# Out:
# ['Toyota', 'Kijang', 'Isuzu', 'Innova', 'Innova']
# ['Toyota', 'Kijang', 'Isuzu']

# %%
kendaraan.remove('Innova')

# %%
buah = ['pisang','jeruk','apel']
buah.pop(1)
print(buah)
# Out:
# ['pisang', 'apel']
