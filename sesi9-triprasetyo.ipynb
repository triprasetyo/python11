# %%
import math
import statistics
import numpy as np
import scipy.stats
import pandas as pd

# %%
x = [8,1,2.5,4,28]
x_with_nan = [8,1,2.5, np.nan,4.28]
print(x)
print(x_with_nan)
# Out:
# [8, 1, 2.5, 4, 28]
# [8, 1, 2.5, nan, 4.28]

# %%
# buat array(y) dan series(z) dari x
y, y_with_nan = np.array(x), np.array(x_with_nan)
z, z_with_nan = pd.Series(x), pd.Series(x_with_nan)

print(y)
print(y_with_nan)
print(z)
print(z_with_nan)
# Out:
# [ 8.   1.   2.5  4.  28. ]
# [8.   1.   2.5   nan 4.28]
# 0     8.0
# 1     1.0
# 2     2.5
# 3     4.0
# 4    28.0
# dtype: float64
# 0    8.00
# 1    1.00
# 2    2.50
# 3     NaN
# 4    4.28
# dtype: float64

# %%
z_with_nan.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool

# %% [markdown]
# # Central Tendency
#
# *   Mean
# *   Weighted mean
# *   Geometric
# *   Harmonic mean
# *   Median
# *   Mode

# %% [markdown]
# # Aritmatic Mean
#
# 1.   x itu list
# 2.   y itu array
# 2.   z itu series

# %%
sum(x)
# Out:
# 43.5

# %%
len(x)
# Out:
# 5

# %%
mean_x = sum(x)/len(x)
mean_x
# Out:
# 8.7

# %%
mean_stats = statistics.mean(x)
print(mean_stats)
# Out:
# 8.7

# %%
mean_np = np.mean(x)
print(mean_np)
# Out:
# 8.7

# %%
y.mean()
# Out:
# 8.7

# %%
z
# Out:
# 0     8.0
# 1     1.0
# 2     2.5
# 3     4.0
# 4    28.0
# dtype: float64

# %%
z.mean()
# Out:
# 8.7

# %%
y_with_nan.mean()
# Out:
# nan

# %%
np.mean(y_with_nan)
# Out:
# nan

# %%
np.nan*3
# Out:
# nan

# %%
# get mean without considering NaN values
np.nanmean(y_with_nan)
# Out:
# 3.9450000000000003

# %%
# series langsung merata-ratakan tanpa mempertimbangkan NaN values
z_with_nan.mean()
# Out:
# 3.9450000000000003

# %%
z_with_nan
# Out:
# 0    8.00
# 1    1.00
# 2    2.50
# 3     NaN
# 4    4.28
# dtype: float64

# %% [markdown]
# # Weighted Mean
# ## Rata-rata dengan menghitung pembobotan

# %%
# metrics
x = [8,1,2.5,4,28] 

#weightages
w = [0.1,0.2,0.3,0.25,0.15] 

# convert jadi array
y,z,w = np.average(x),pd.Series(x),np.array(w)

# wmean = np.average(y, weights=w)
# print(wmean)

# %%
# manual calculation

wmean_manual = sum(w[i] * x[i] for i in range(len(x)))/sum(w)
print(wmean_manual)
# Out:
# 6.95

# %%
sum(w)
# Out:
# 1.0

# %% [markdown]
# # Harmonic Mean
# ## Sering digunakan untuk rata-rata rate (10/km, 100kg/hari, 1000000 orang/tahun)

# %%
speed = [60,20]
hmean_speed = len(speed)/sum(1/item for item in speed)
hmean_speed
# Out:
# 30.0

# %%
# hmean dengan library 1
hmean_speed_stats = statistics.harmonic_mean(speed)
hmean_speed_stats
# Out:
# 30.0

# %%
# hmean dengan library 2
hmean_speed_stats2 = scipy.stats.hmean(x)
hmean_speed_stats2
# Out:
# 2.7613412228796843

# %%
hmean = len(x) / sum(1/item for item in x)
hmean
# Out:
# 2.7613412228796843

# %%
x
# Out:
# [8, 1, 2.5, 4, 28]

# %%
for item in x:
  print(1/item)
# Out:
# 0.125
# 1.0
# 0.4
# 0.25
# 0.03571428571428571

# %%
sum(1/item for item in x)
# Out:
# 1.8107142857142857

# %%
# hmean dengan library
hmean_stats = statistics.harmonic_mean(x)
hmean_stats
# Out:
# 2.7613412228796843

# %% [markdown]
# # Geometric Mean
#
# Perusahaan berdiri pada tahun 2017
# *   Tahun 2017 omsetnya 1000
# *   Tahun 2018 naik 30%
# *   Tahun 2019 naik 50%
# *   Tahun 2020 naik 40%

# %%
 x = 1000
 x *= 1.3 # 1300
 x *= 1.5 # 1950
 x *= 1.4 # 2730
 x
# Out:
# 2730.0

# %%
# aritmatic mean
(30+50+40)/3
# Out:
# 40.0

# %%
x = 1000
x *= 1.4
x *= 1.4
x *= 1.4
x
# Out:
# 2743.9999999999995

# %%
# geometric mean
gmean = ((30*50*40)**(1/3))    
gmean
# Out:
# 39.148676411688626

# %%
x = 1000
x *= 1.3915
x *= 1.3915
x *= 1.3915
x
# Out:
# 2694.322835875

# %%
# geomatric mean menggunakan library scipy
scipy.stats.gmean([30,40,50])
# Out:
# 39.14867641168864

# %% [markdown]
# # Median

# %%
# ganjil
a = [1,2,4,8,9]

n = len(a)
n
# Out:
# 5

# %%
median = a[2]
median
# Out:
# 4

# %%
# genap
a = [1,2,4,8]
a = len(a)
(a+1)/2
median = (2+4)/2
median
# Out:
# 3.0

# %%
# menggunaka numpy
x = [8,1,2.5,4,28]
c = [2,3,4,5]
np.median(x)
np.median(c)
# Out:
# 3.5

# %%
# pembuktian manual
def median_function(x):
  n = len(x)
  if n%2 == 1: # ganjil
    median_ = sorted(x)[round(0.5*(n-1))] # ambil median
  else : # genap
    x_ord, index = sorted(x), round(0.5*n)
    median_ = 0.5* (x_ord[index-1]+x_ord[index])
  return median_

# %%
median_function(x)
# Out:
# 4

# %%
median_function(c)
# Out:
# 3.5

# %%
sorted(x)
# Out:
# [1, 2.5, 4, 8, 28]

# %%
n = len(x)
round(0.5*(n-1))
# Out:
# 2

# %%
n
# Out:
# 5

# %%
7%2
# Out:
# 1

# %%
6%2
# Out:
# 0

# %% [markdown]
# # Mode / Modus
# Nilai yang paling sering banyak muncul/frekuensi paling tinggi

# %%
u = [2,3,2,8,12]

mode_ = max((u.count(i),i)for i in set(u))[1]

# %%
statistics.mode(u)
# Out:
# 2

# %%
scipy.stats.mode(u)[0][0]
# Out:
# <ipython-input-73-d8f8f9254a13>:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   scipy.stats.mode(u)[0][0]
# 2

# %%
scipy.stats.mode(u)[0][0]
# Out:
# <ipython-input-74-d8f8f9254a13>:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   scipy.stats.mode(u)[0][0]
# 2

# %%
mode_lib = scipy.stats.mode(u)[0][0]
# Out:
# <ipython-input-75-3d332761fc48>:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_lib = scipy.stats.mode(u)[0][0]

# %%
print(mode_lib)
# print(mode_lib.mode) 
# print(mode_lib.count)
# Out:
# 2

# %%
u
# Out:
# [2, 3, 2, 8, 12]

# %%
u_series = pd.Series(u)
u_series.mode()
# Out:
# 0    2
# dtype: int64

# %%
u_array = np.array(u)
statistics.mode(u_array)
# Out:
# 2

# %%
v = pd.Series([1,2,3,3,3,np.nan])
v.mode()
# Out:
# 0    3.0
# dtype: float64

# %%
statistics.mode(v)
# Out:
# 3.0

# %%
h = [1,2,3,3,3,np.nan,np.nan,np.nan,np.nan]
statistics.mode(h)
# Out:
# nan

# %%
set([1,1,1,2,3,4,5])
# Out:
# {1, 2, 3, 4, 5}

# %%
u.count(12)
# Out:
# 1

# %% [markdown]
# ## Series akan mengabaikan NaN dan List akan mempertimbangkan NaN

# %% [markdown]
# # Measures of Variability

# %% [markdown]
# ## Variance

# %%
x
# Out:
# [8, 1, 2.5, 4, 28]

# %%
n = len(x)
mean_var = np.mean(x)
var_ = sum((item-mean_var)**2 for item in x)/(n-1)
var_
# Out:
# 123.19999999999999

# %%
# variance w/ statistics library 
var_stat = statistics.variance(x)
var_stat
# Out:
# 123.2

# %%
# variance w/ numpy
var_np = np.var(x,ddof=1)
var_np
# Out:
# 123.19999999999999

# %%
# variance using series function
z = pd.Series(x)
z.var()
# Out:
# 123.19999999999999

# %% [markdown]
# # Standar Deviasi
# ## Hitung variance dan standar deviasi

# %%
# dengan menggunakan library

x = [1,2,3,6,7,8,30,40,50]

std_dev = statistics.stdev(x)
print("Standar Deviasi dri x adalah : ",std_dev)

variance = statistics.variance(x)
print("Variasi dari x adalah ", variance)
# Out:
# Standar Deviasi dri x adalah :  18.58090417606205
# Variasi dari x adalah  345.25000000000006

# %%
# dengan menggunakan manual
x = [1,2,3,6,7,8,30,40,50]
n = len(x)

mean = sum(x)/n
var = sum((item-mean)**2 for item in x)/(n-1)
sd_ = var_**(1/2)

print(var_)
print(sd_)
# Out:
# 123.19999999999999
# 11.099549540409285

# %%
x = [8,1,2.5,4,28]

# %%
var_np
# Out:
# 123.19999999999999

# %%
stdev = var_np**(1/2)

# %%
stdev
# Out:
# 11.099549540409285

# %%
stdev = np.sqrt(var_np)
stdev
# Out:
# 11.099549540409285

# %%
# stdev with statistics library
stdev = statistics.stdev(x)
stdev
# Out:
# 11.099549540409287

# %%
stdev - np.std(x, ddof=1)
stdev
# Out:
# 11.099549540409287

# %% [markdown]
# # SKewness

# %%
x
# Out:
# [8, 1, 2.5, 4, 28]

# %%
n = len(x)
mean = np.mean(x)
stdev = statistics.stdev(x)
skew_ = (sum((item - mean)**3 for item in x))*n / ((n-1)*(n-2)*(stdev**3))
skew_
# Out:
# 1.947043227390592

# %%
scipy.stats.skew(x,bias=False)
# Out:
# 1.9470432273905927

# %%
z = pd.Series(x)
z.skew()
# Out:
# 1.9470432273905924

# %%
scipy.stats.skew(x_with_nan)
# Out:
# nan

# %%
z_with_nan = pd.Series(x_with_nan)
z_with_nan.skew()
# Out:
# 0.9257784636185135

# %%
scipy.stats.skew(z_with_nan)
# Out:
# nan

# %% [markdown]
# # Percentiles

# %%
x = [-5,-1.1,0.1,2,8,12,8,21,25.8,41]
np.percentile(x,5)
# Out:
# -3.245

# %%
np.percentile(x,0)
# Out:
# -5.0

# %%
np.percentile(x,90)
# Out:
# 27.319999999999997

# %%
statistics.quantiles(x,n=2)
# Out:
# [8.0]

# %%
statistics.quantiles(x,n=4)
# Out:
# [-0.2, 8.0, 22.2]

# %%
statistics.quantiles(x,n=4,method='inclusive')
# Out:
# [0.575, 8.0, 18.75]

# %%
x
# Out:
# [-5, -1.1, 0.1, 2, 8, 12, 8, 21, 25.8, 41]

# %%
np.quantile(x,0)
# Out:
# -5.0

# %%
np.quantile(x,1)
# Out:
# 41.0

# %%
np.quantile(x,0.5)
# Out:
# 8.0

# %%
x
# Out:
# [-5, -1.1, 0.1, 2, 8, 12, 8, 21, 25.8, 41]

# %%
x_with_nan = [-5, -1.1, np.nan, 0.1, 2, 8, 12.8, 21, 25.8, 41]
x_with_nan
# Out:
# [-5, -1.1, nan, 0.1, 2, 8, 12.8, 21, 25.8, 41]

# %%
np.quantile(x_with_nan,0)
# Out:
# nan

# %%
np.quantile(x_with_nan,0.5)
# Out:
# nan

# %%
x
# Out:
# [-5, -1.1, 0.1, 2, 8, 12, 8, 21, 25.8, 41]

# %%
np.quantile(x,[0.25,0.5,0.75])
# Out:
# array([ 0.575,  8.   , 18.75 ])

# %%
statistics.quantiles(x,n=4,method='inclusive')
# Out:
# [0.575, 8.0, 18.75]

# %%
np.percentile(x,[25,50,75])
# Out:
# array([ 0.575,  8.   , 18.75 ])

# %% [markdown]
# # Range (nilai Max - nilai Min)

# %%
x
# Out:
# [-5, -1.1, 0.1, 2, 8, 12, 8, 21, 25.8, 41]

# %%
np.ptp(x)
# Out:
# 46.0

# %%
np.max(x)
# Out:
# 41.0

# %%
np.min(x)
# Out:
# -5.0

# %%
np.amax(x) - np.amin(x)
# Out:
# 46.0

# %% [markdown]
# # Interquartile Range (Q3-Q1) (biasanya digunakan untuk mendeteksi outlier)

# %%
x
# Out:
# [-5, -1.1, 0.1, 2, 8, 12, 8, 21, 25.8, 41]

# %%
quartiles = np.quantile(x,[0.25,0.75])
IQR = quartiles[1] - quartiles[0]
IQR
# Out:
# 18.175

# %% [markdown]
# # Summary of Desc. Stats

# %%
x
# Out:
# [-5, -1.1, 0.1, 2, 8, 12, 8, 21, 25.8, 41]

# %%
result = scipy.stats.describe(x,ddof=1,bias=False)
result
# Out:
# DescribeResult(nobs=10, minmax=(-5.0, 41.0), mean=11.18, variance=204.43733333333336, skewness=1.0597458790815801, kurtosis=0.6706212180772724)

# %%
(result.variance)**(1/2)
# Out:
# 14.29815838957358

# %%
result.minmax[1]-result.minmax[0]
# Out:
# 46.0

# %%
result.skewness
# Out:
# 1.0597458790815801

# %%
z = pd.Series(x)
z
# Out:
# 0    -5.0
# 1    -1.1
# 2     0.1
# 3     2.0
# 4     8.0
# 5    12.0
# 6     8.0
# 7    21.0
# 8    25.8
# 9    41.0
# dtype: float64

# %%
z.describe()
# Out:
# count    10.000000
# mean     11.180000
# std      14.298158
# min      -5.000000
# 25%       0.575000
# 50%       8.000000
# 75%      18.750000
# max      41.000000
# dtype: float64

# %% [markdown]
# # Correlation

# %%
x = list(range(-10,11))
y = [0,2,2,2,2,3,3,6,7,4,7,6,6,9,4,5,5,10,11,12,14]
x_ar, y_ar = np.array(x),np.array(y)
x_s,y_s = pd.Series(x),pd.Series(y)

# %%
len(x) == len(y)
# Out:
# True

# %% [markdown]
# # Covariance

# %%
n = len(x)
mean_x = np.mean(x)
mean_y = np.mean(y)

cov_xy = (sum((x[item]-mean_x)*(y[item]-mean_y) for item in range(n)))/(n-1)
cov_xy
# Out:
# 19.95

# %% [markdown]
# # Covariance Matrix Formula

# %%
cov_matrix = np.cov(x,y)
cov_matrix
# Out:
# array([[38.5       , 19.95      ],
#        [19.95      , 13.91428571]])

# %%
np.var(y,ddof=1)
# Out:
# 13.914285714285711

# %%
cov_xy = cov_matrix[1,0]
cov_xy
# Out:
# 19.95

# %%
cov_xy = cov_matrix[1,0]
cov_xy
# Out:
# 19.95

# %% [markdown]
# # Coviance Coefficient

# %%
var_x = np.var(x,ddof=1)
var_y = np.var(y,ddof=1)
cov_xy
std_x = var_x**(1/2)
std_y = var_y**(1/2)
r = cov_xy / (std_x**std_y)
r
# Out:
# 0.02202477048576318

# %%
r,p = scipy.stats.pearsonr(x,y)
r
# Out:
# 0.8619500056316061

# %%
p
# Out:
# 5.122760847201132e-07
